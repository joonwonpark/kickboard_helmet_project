# %%
import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
tf.debugging.set_log_device_placement(True)

# %%
# gpus = tf.config.experimental.list_physical_devices('GPU')
gpus = tf.distribute.MirroredStrategy()
if gpus:
    try:
    # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_116148/3054485269.py in <module>
#       4     try:
#       5     # Currently, memory growth needs to be the same across GPUs
# ----> 6         for gpu in gpus:
#       7             tf.config.experimental.set_memory_growth(gpu, True)
#       8             logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#
# TypeError: 'MirroredStrategy' object is not iterable

# %%
TRAINING_DIR = "/root/data/cut_data_limit10000/train/"
VALIDATION_DIR = "/root/data/cut_data_limit10000/validation/"
TEST_DIR = "/root/data/cut_data_limit10000/test/"

# %%
training_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='reflect', 
    validation_split=0.2
    )

# %%
training_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                          batch_size=32, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical', 
                                                          subset='training',
                                                         )
# Out:
# Found 51342 images belonging to 3 classes.

# %%
validation_generator = training_datagen.flow_from_directory(VALIDATION_DIR, 
                                                          batch_size=32, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical',
                                                          subset='validation', 
                                                         )
# Out:
# Found 1151 images belonging to 3 classes.

# %%
model = Sequential([
    # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2), 
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2), 
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2), 
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2), 
    # 2D -> 1D로 변환을 위하여 Flatten 합니다.
    Flatten(), 
    # 과적합 방지를 위하여 Dropout을 적용합니다.
    Dropout(0.5),
    Dense(128, activation='relu'),
    # Classification을 위한 Softmax 
    # 출력층의 갯수는 클래스의 갯수와 동일하게 맞춰줍니다 (3개), activation도 잊지마세요!
    Dense(2, activation='softmax'),
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

checkpoint_path = f"/root/data/model/cut_data_tmp_checkpoint.ckpt"
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                            save_weights_only=True, 
                            save_best_only=True, 
                            monitor='val_loss', 
                            verbose=1)
epochs=30
history = model.fit(training_generator, 
                    validation_data=(validation_generator),
                    epochs=epochs,
                    callbacks=[checkpoint],
                    )

model.load_weights(checkpoint_path)

loss = model.evaluate(validation_generator)[0]
acc = model.evaluate(validation_generator)[1]

model.save(f"/root/data/model/cut_data_model.h5")
# Out:
# Epoch 1/30
# 2021-11-12 22:25:01.218490: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-11-12 22:25:11.347714: W tensorflow/core/common_runtime/bfc_allocator.cc:431] Allocator (GPU_0_bfc) ran out of memory trying to allocate 384B (rounded to 512)requested by op SameWorkerRecvDone
# Current allocation summary follows.
# 2021-11-12 22:25:11.347781: I tensorflow/core/common_runtime/bfc_allocator.cc:970] BFCAllocator dump for GPU_0_bfc
# 2021-11-12 22:25:11.347801: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (256): 	Total Chunks: 43, Chunks in use: 43. 10.8KiB allocated for chunks. 10.8KiB in use in bin. 1.3KiB client-requested in use in bin.
# 2021-11-12 22:25:11.347813: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin
I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2f02900 of size 15587072 next 18446744073709551615
# 2021-11-12 22:25:11.349862: I tensorflow/core/common_runtime/bfc_allocator.cc:1031]      Summary of in-use Chunks by size:
# 2021-11-12 22:25:11.349873: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 43 Chunks of size 256 totalling 10.8KiB
# 2021-11-12 22:25:11.349882: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 8 Chunks of size 512 totalling 4.0KiB
# 2021-11-12 22:25:11.349890: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 768 totalling 768B
# 2021-11-12 22:25:11.349899: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 3 Chunks of size 1024 totalling 3.0KiB
# 2021-11-12 22:25:11.349907: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 1280 totalling 1.2KiB
# 2021-11-12 22:25:11.349916: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 3 Chunks of size 3584 totalling 10.5KiB
# 2021-11-12 22:25:11.349925: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 2 Chunks of size 73728 totalling 144.0KiB
# 2021-11-12 22:25:11.349935: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 142336 totalling 139.0KiB
# 2021-11-12 22:25:11.349944: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 294912 totalling 288.0KiB
# 2021-11-12 22:25:11.349953: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 509184 totalling 497.2KiB
# 2021-11-12 22:25:11.349962: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 589568 totalling 575.8KiB
# 2021-11-12 22:25:11.349970: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 3 Chunks of size 589824 totalling 1.69MiB
# 2021-11-12 22:25:11.349979: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 2 Chunks of size 3211264 totalling 6.12MiB
# 2021-11-12 22:25:11.349987: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 5832704 totalling 5.56MiB
# 2021-11-12 22:25:11.349996: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 15587072 totalling 14.86MiB
# 2021-11-12 22:25:11.350005: I tensorflow/core/common_runtime/bfc_allocator.cc:1038] Sum Total of in-use chunks: 29.88MiB
# 2021-11-12 22:25:11.350013: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] total_region_allocated_bytes_: 31326208 memory_limit_: 31326208 available bytes: 0 curr_region_allocation_bytes_: 62652416
# 2021-11-12 22:25:11.350027: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Stats:
# Limit:                        31326208
# InUse:                        31326208
# MaxInUse:                     31326208
# NumAllocs:                         189
# MaxAllocSize:                 15587072
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2021-11-12 22:25:11.350042: W tensorflow/core/common_runtime/bfc_allocator.cc:439] ********************xxxxxxx***************************************************xxxxxxxxxxxxxxxxxxxxxx
# 2021-11-12 22:25:11.350094: W tensorflow/core/common_runtime/bfc_allocator.cc:431] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.24MiB (rounded to 8640000)requested by op gradient_tape/sequential/conv2d/Conv2D/Conv2DBackpropFilter-0-TransposeNHWCToNCHW-LayoutOptimizer
# Current allocation summary follows.
# 2021-11-12 22:25:11.350123: I tensorflow/core/common_runtime/bfc_allocator.cc:970] BFCAllocator dump for GPU_0_bfc
# 2021-11-12 22:25:11.350155: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (256): 	Total Chunks: 43, Chunks in use: 43. 10.8KiB allocated for chunks. 10.8KiB in use in bin. 1.3KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350169: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (512): 	Total Chunks: 9, Chunks in use: 9. 4.8KiB allocated for chunks. 4.8KiB in use in bin. 4.5KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350180: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (1024): 	Total Chunks: 4, Chunks in use: 4. 4.2KiB allocated for chunks. 4.2KiB in use in bin. 4.0KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350192: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (2048): 	Total Chunks: 3, Chunks in use: 3. 10.5KiB allocated for chunks. 10.5KiB in use in bin. 10.1KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350202: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350212: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350221: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350231: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350248: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (65536): 	Total Chunks: 2, Chunks in use: 2. 144.0KiB allocated for chunks. 144.0KiB in use in bin. 144.0KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350265: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 139.0KiB allocated for chunks. 139.0KiB in use in bin. 72.0KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350278: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 785.2KiB allocated for chunks. 785.2KiB in use in bin. 576.0KiB client-requested in use in bin.
# 2021-11-12 22:25:11.350289: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (524288): 	Total Chunks: 4, Chunks in use: 4. 2.25MiB allocated for chunks. 2.25MiB in use in bin. 1.97MiB client-requested in use in bin.
# 2021-11-12 22:25:11.350298: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350309: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (2097152): 	Total Chunks: 2, Chunks in use: 2. 6.12MiB allocated for chunks. 6.12MiB in use in bin. 6.12MiB client-requested in use in bin.
# 2021-11-12 22:25:11.350319: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 5.56MiB allocated for chunks. 5.56MiB in use in bin. 3.06MiB client-requested in use in bin.
# 2021-11-12 22:25:11.350331: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 14.86MiB allocated for chunks. 14.86MiB in use in bin. 8.24MiB client-requested in use in bin.
# 2021-11-12 22:25:11.350341: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350350: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350362: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350377: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350387: I tensorflow/core/common_runtime/bfc_allocator.cc:977] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 22:25:11.350397: I tensorflow/core/common_runtime/bfc_allocator.cc:993] Bin for 8.24MiB was 8.00MiB, Chunk State:
# 2021-11-12 22:25:11.350405: I tensorflow/core/common_runtime/bfc_allocator.cc:1006] Next region of size 31326208
# 2021-11-12 22:25:11.350416: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000000 of size 1280 next 1
# 2021-11-12 22:25:11.350425: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000500 of size 256 next 2
# 2021-11-12 22:25:11.350432: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000600 of size 256 next 6
# 2021-11-12 22:25:11.350440: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000700 of size 256 next 9
# 2021-11-12 22:25:11.350448: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000800 of size 256 next 11
# 2021-11-12 22:25:11.350455: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000900 of size 256 next 12
# 2021-11-12 22:25:11.350464: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000a00 of size 256 next 10
# 2021-11-12 22:25:11.350476: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000b00 of size 256 next 16
# 2021-11-12 22:25:11.350487: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000c00 of size 256 next 17
# 2021-11-12 22:25:11.350497: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000d00 of size 512 next 15
# 2021-11-12 22:25:11.350506: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2000f00 of size 256 next 20
# 2021-11-12 22:25:11.350514: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001000 of size 256 next 21
# 2021-11-12 22:25:11.350523: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001100 of size 768 next 3
# 2021-11-12 22:25:11.350532: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001400 of size 256 next 4
# 2021-11-12 22:25:11.350541: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001500 of size 256 next 5
# 2021-11-12 22:25:11.350550: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001600 of size 256 next 25
# 2021-11-12 22:25:11.350559: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001700 of size 256 next 26
# 2021-11-12 22:25:11.350568: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001800 of size 512 next 24
# 2021-11-12 22:25:11.350576: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001a00 of size 256 next 32
# 2021-11-12 22:25:11.350585: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001b00 of size 256 next 34
# 2021-11-12 22:25:11.350595: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001c00 of size 256 next 35
# 2021-11-12 22:25:11.350607: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001d00 of size 256 next 29
# 2021-11-12 22:25:11.350616: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001e00 of size 256 next 30
# 2021-11-12 22:25:11.350624: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2001f00 of size 256 next 31
# 2021-11-12 22:25:11.350631: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2
I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2f02800 of size 256 next 71
# 2021-11-12 22:25:11.351044: I tensorflow/core/common_runtime/bfc_allocator.cc:1026] InUse at 7f51b2f02900 of size 15587072 next 18446744073709551615
# 2021-11-12 22:25:11.351052: I tensorflow/core/common_runtime/bfc_allocator.cc:1031]      Summary of in-use Chunks by size:
# 2021-11-12 22:25:11.351065: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 43 Chunks of size 256 totalling 10.8KiB
# 2021-11-12 22:25:11.351075: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 8 Chunks of size 512 totalling 4.0KiB
# 2021-11-12 22:25:11.351084: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 768 totalling 768B
# 2021-11-12 22:25:11.351096: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 3 Chunks of size 1024 totalling 3.0KiB
# 2021-11-12 22:25:11.351108: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 1280 totalling 1.2KiB
# 2021-11-12 22:25:11.351119: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 3 Chunks of size 3584 totalling 10.5KiB
# 2021-11-12 22:25:11.351129: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 2 Chunks of size 73728 totalling 144.0KiB
# 2021-11-12 22:25:11.351139: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 142336 totalling 139.0KiB
# 2021-11-12 22:25:11.351149: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 294912 totalling 288.0KiB
# 2021-11-12 22:25:11.351160: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 509184 totalling 497.2KiB
# 2021-11-12 22:25:11.351170: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 589568 totalling 575.8KiB
# 2021-11-12 22:25:11.351180: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 3 Chunks of size 589824 totalling 1.69MiB
# 2021-11-12 22:25:11.351190: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 2 Chunks of size 3211264 totalling 6.12MiB
# 2021-11-12 22:25:11.351200: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 5832704 totalling 5.56MiB
# 2021-11-12 22:25:11.351213: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] 1 Chunks of size 15587072 totalling 14.86MiB
# 2021-11-12 22:25:11.351226: I tensorflow/core/common_runtime/bfc_allocator.cc:1038] Sum Total of in-use chunks: 29.88MiB
# 2021-11-12 22:25:11.351234: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] total_region_allocated_bytes_: 31326208 memory_limit_: 31326208 available bytes: 0 curr_region_allocation_bytes_: 62652416
# 2021-11-12 22:25:11.351246: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Stats:
# Limit:                        31326208
# InUse:                        31326208
# MaxInUse:                     31326208
# NumAllocs:                         189
# MaxAllocSize:                 15587072
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2021-11-12 22:25:11.351260: W tensorflow/core/common_runtime/bfc_allocator.cc:439] ********************xxxxxxx***************************************************xxxxxxxxxxxxxxxxxxxxxx
# 2021-11-12 22:25:11.351290: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at transpose_op.cc:198 : Resource exhausted: OOM when allocating tensor with shape[32,3,150,150] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_116148/2574995850.py in <module>
#      31                     validation_data=(validation_generator),
#      32                     epochs=epochs,
# ---> 33                     callbacks=[checkpoint],
#      34                     )
#      35
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     838         # Lifting succeeded, so variables are initialized and we can run the
#     839         # stateless function.
# --> 840         return self._stateless_fn(*args, **kwds)
#     841     else:
#     842       canon_args, canon_kwds = \
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/gpu_env/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# InternalError:  Dst tensor is not initialized.
# 	 [[{{node IteratorGetNext/_4}}]] [Op:__inference_train_function_1039]
#
# Function call stack:
# train_function

# %%
# Out:
# Physical devices cannot be modified after being initialized
